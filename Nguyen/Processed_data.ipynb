# %%
import import_ipynb
from sklearn.preprocessing import StandardScaler
import numpy as np
# from train_test_split import *

# %%
x_train = torch.load('data_train.pt')
x_test = torch.load('data_test.pt')
y_train = torch.load('label_train.pt')
y_test = torch.load('label_test.pt')

# %% [markdown]
# ## Scaler

# %%
#feature scalling
def StandardScalling(x_train, x_test):
    scaler = StandardScaler()

    N,H,W = x_train.shape # N: number of sample, W: weight, H: height
    # standard scale use for only 1-D array
    x_train = np.reshape(x_train, (N, -1))
    x_train = scaler.fit_transform(x_train)
    x_train = np.reshape(x_train, (N,H,W))

    N,H,W = x_test.shape # N: number of sample, W: weight, H: height
    # standard scale use for only 1-D array
    x_test = np.reshape(x_test, (N, -1))
    x_test = scaler.fit_transform(x_test)
    x_test = np.reshape(x_test, (N,H,W))    

    return x_train, x_test

# %%
test_train, test_test = StandardScalling(x_train,x_test)

# %%
test_train
# Out:
# array([[[-0.85033411, -0.82655798, -0.87359245, ..., -1.06382492,
#          -0.85888235, -0.74856868],
#         [-0.85486668, -0.92792723, -1.11349171, ...,  0.88425083,
#          -0.12484985, -0.5913921 ],
#         [-1.47181326, -1.41053707, -1.29490231, ...,  0.1816313 ,
#           1.21383089,  1.88261939],
#         ...,
#         [-0.55831412, -1.29570119,  0.39607754, ..., -0.60844876,
#          -0.87671903, -1.54084755],
#         [ 0.81564789, -0.6885231 ,  1.02124348, ..., -0.90104151,
#           0.42103862, -0.40299395],
#         [-1.81489537, -1.82292977, -0.84070192, ..., -0.36691825,
#           0.20829942,  0.89589393]],
#
#        [[-0.705178  , -0.76771564, -0.61581883, ...,  1.0302122 ,
#           0.70114849,  0.48647458],
#         [ 0.32279839,  0.25930134,  0.4759695 , ...,  0.31767062,
#           0.43300528,  0.24294388],
#         [ 0.93824599,  1.09958221,  1.03788338, ..., -0.32349481,
#          -0.18656375, -0.14057401],
#         ...,
#         [ 1.6474035 ,  1.22922889, -0.03888185, ..., -0.18213873,
#          -0.07117975, -0.05745631],
#         [ 0.25712727, -0.92486044, -0.79631283, ...,  0.73461148,
#           0.62529895,  0.98988955],
#         [-0.23418131,  0.53956472,  0.49635281, ...,  0.70833346,
#          -0.51508759,  0.48329437]],
#
#        [[ 2.0747306 ,  2.51882157,  2.73012671, ...,  3.04754084,
#           3.01197598,  2.94273995],
#         [ 1.84386635,  1.70309628,  1.82698961, ..., -0.40442375,
#          -0.43630392, -0.16743164],
#         [-0.5370544 , -1.38753985, -1.95596687, ..., -3.11484177,
#          -3.23818374, -3.08851312],
#         ...,
#         [ 0.31250756, -0.56255516, -2.82330496, ..., -1.16799303,
#           0.68289447, -1.47664066],
#         [ 1.73274083,  1.12151462, -0.50815035, ..., -0.23839822,
#           1.16575024,  0.50525034],
#         [ 1.64788426,  0.68620097, -0.64837989, ..., -0.4976405 ,
#          -0.08995823, -0.20621349]],
#
#        ...,
#
#        [[-0.91674045, -1.0667424 , -0.95554381, ..., -0.98152105,
#          -1.09962227, -1.06303998],
#         [ 0.24703468,  0.04646235,  0.73653768, ...,  0.11298973,
#           0.42279566,  0.2683727 ],
#         [ 0.24665754,  0.34557815,  0.46397488, ..., -0.27469828,
#           0.11761498,  0.26135207],
#         ...,
#         [-0.55285942,  0.85011298,  1.82538433, ...,  0.3588251 ,
#           0.3830738 ,  0.05472405],
#         [ 1.57314758,  0.25587477,  1.22028822, ..., -0.50513783,
#           0.24688497,  0.32241398],
#         [ 1.0496963 ,  0.88942579, -0.75323975, ..., -0.33753774,
#           0.29105497, -0.82838321]],
#
#        [[ 0.36556417,  0.43442154,  0.57140435, ..., -0.30316241,
#          -0.10274732, -0.18925114],
#         [ 0.43002763,  0.34323452,  0.3119579 , ..., -2.46655424,
#          -3.09254715, -3.33364763],
#         [-1.88282829, -1.74339404, -2.51641965, ...,  1.16811359,
#           0.45961701,  1.0779374 ],
#         ...,
#         [-0.77335198, -0.23143873,  1.04106725, ...,  0.18051648,
#           0.69033542,  0.13167209],
#         [ 0.05261114,  1.53039815,  0.89641471, ...,  1.1443174 ,
#           1.77910504,  0.82692294],
#         [ 0.8826679 ,  0.36528223,  0.3416257 , ..., -0.01816662,
#           0.94019266,  0.49299861]],
#
#        [[-0.27823179, -0.256151  , -0.27404083, ..., -0.78222531,
#          -0.82745539, -0.7201552 ],
#         [ 1.23959948,  1.07082931,  1.05501028, ...,  0.23110452,
#           0.11691763,  0.2623978 ],
#         [ 0.0747553 , -0.16068478,  0.12639674, ...,  0.40821308,
#          -0.02388927,  0.43146603],
#         ...,
#         [-1.20094572, -1.44561384, -1.31012153, ...,  0.14334516,
#           0.37823291, -1.12504502],
#         [ 0.04058217, -0.18630884,  0.44957809, ...,  0.30454101,
#           1.14542791, -0.59203156],
#         [-2.29585501, -0.61756338, -0.74621264, ..., -0.36867982,
#           0.68471558,  0.40556468]]])

# %%
x_train
# Out:
# tensor([[[-5.3326e+02, -5.1674e+02, -5.2158e+02,  ..., -5.0547e+02,
#           -4.8210e+02, -4.6951e+02],
#          [ 4.1372e+01,  5.1749e+01,  4.6744e+01,  ...,  1.1066e+02,
#            7.3169e+01,  5.6484e+01],
#          [-6.0397e+01, -6.5991e+01, -6.3002e+01,  ..., -3.5748e+01,
#           -7.0745e-01,  2.2494e+01],
#          ...,
#          [-1.1323e+01, -1.4405e+01, -4.6878e+00,  ..., -1.2625e+01,
#           -1.4264e+01, -1.8545e+01],
#          [-2.9265e+00, -1.4128e+01, -4.2026e+00,  ..., -1.6311e+01,
#           -7.6199e+00, -1.2979e+01],
#          [-2.1119e+01, -1.8919e+01, -1.3448e+01,  ..., -1.1872e+01,
#           -8.3873e+00, -4.2365e+00]],
#
#         [[-5.1961e+02, -5.1167e+02, -4.9927e+02,  ..., -2.6634e+02,
#           -3.0366e+02, -3.2777e+02],
#          [ 7.5837e+01,  8.3576e+01,  8.8969e+01,  ...,  8.9499e+01,
#            9.3866e+01,  8.6867e+01],
#          [-3.1295e+00, -1.9822e+00, -3.4101e+00,  ..., -5.2977e+01,
#           -4.8782e+01, -4.7323e+01],
#          ...,
#          [ 5.5176e+00,  8.6256e-02, -7.1983e+00,  ..., -9.8399e+00,
#           -9.0830e+00, -9.0192e+00],
#          [-7.1668e+00, -1.5495e+01, -1.4868e+01,  ..., -5.6504e+00,
#           -6.2763e+00, -3.8555e+00],
#          [-9.3916e+00, -5.8866e+00, -6.0860e+00,  ..., -5.2160e+00,
#           -1.2846e+01, -6.7730e+00]],
#
