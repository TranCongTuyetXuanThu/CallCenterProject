# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dpl-project-1/model88.pt
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_05.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_03.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_10.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_09.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_7.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_9.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_8.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_12.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_01.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_08.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_06.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_11.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_18.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_04.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_17.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_14.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_3.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_05.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_11.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_09.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_10.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_13.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_15.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_11.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_02.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_11.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_06.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_06.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_13.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_5.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_10.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_02.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_15.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_16.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_04.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_07.mp4
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_13.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_01.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_07.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_08.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_03.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_07.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_08.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_03.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_01.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_05.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_12.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_12.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_02.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_13.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_6.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_09.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_2.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_4.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_12.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_15.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_04.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Nhat_10.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_1.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_16.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_05.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_20.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_03.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_10.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_12.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_05.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_03.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_13.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_7.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_9.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_08.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_06.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_8.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_12.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_01.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_15.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_22.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_06.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_11.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_18.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_04.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_15.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_04.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_02.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_10.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_06.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_3.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_11.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_08.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_10.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_15.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_15.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_02.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_11.mp4
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_06.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_19.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_05.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_12.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_14.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_13.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_23.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_5.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_17.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_07.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_07.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_10.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_09.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_14.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_01.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_13.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_13.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_21.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_03.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_07.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_16.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_03.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_14.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_09.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_08.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_10.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_08.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_05.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_01.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_12.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_11.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_11.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_07.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/chien_02.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/anh_04.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_6.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_24.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_09.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_09.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_2.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_4.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_02.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_17.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_13.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_15.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_04.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/Nhat_01.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/negative/tinh_1.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_16.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_05.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_03.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_10.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_12.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_09.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_13.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_7.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_9.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_8.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_07.mp3
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_12.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_11.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_01.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_06.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_11.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_12.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_15.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_04.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_02.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_17.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_10.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_06.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_14.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_3.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_05.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_11.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_09.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_13.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_15.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_15.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_11.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_02.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_06.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_05.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_14.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_06.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_13.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_5.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_17.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_07.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_10.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_09.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_02.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_15.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_16.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_01.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_08.mp4
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_04.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_14.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_13.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_01.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_03.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_07.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_08.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_17.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_03.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_07.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_08.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_03.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_08.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_01.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_05.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_12.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_16.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_11.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_12.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_02.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_13.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/anh_04.wav
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_6.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_09.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_2.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_4.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_15.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_10.mp4
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_04.m4a
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_10.aac
# /kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_1.m4a
# /kaggle/input/update-mode/model78.pt

# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /opt/conda/lib/python3.10/site-packages (from ffmpeg-python) (0.18.3)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %%
import subprocess, os, csv
from torch import nn
import torch, torchaudio, statistics
from pydub import AudioSegment
from pydub.silence import detect_nonsilent
import pandas as pd
import warnings, shutil
import ffmpeg

# %%
# suppress all warnings
warnings.filterwarnings("ignore")
# suppress only the UserWarning with message "At least one mel filterbank has all zero values."
warnings.filterwarnings("ignore")

# %%
# Model flow
class define_model(nn.Module):

    # Define layers
    def __init__(self, num_emotions):
        super().__init__()

        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, #####################
            nhead=4,
            dim_feedforward=512,
            dropout=0.4,
            activation='relu'
        )
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)

        #maxpool: reshape (width, height)
        #conv: reshape (channel)
        conv2d_layer = nn.Sequential(
            nn.Conv2d(
                in_channels=2,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(16),#######
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            nn.Conv2d(
                in_channels=16,
                out_channels=32,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(32),#######
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(64),#######
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        self.conv2Dblock1 = nn.Sequential(
            nn.Conv2d(
                in_channels=2,
                out_channels=16,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            nn.Conv2d(
                in_channels=16,
                out_channels=32,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            nn.Conv2d(
                in_channels=32,
                out_channels=64,
                kernel_size=3,
                stride=1,
                padding=1
            ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        self.conv2Dblock2 = conv2d_layer

        self.fc1_layer = nn.Linear(1792*2+40, 1800)
        self.act1 = nn.ReLU()
        self.fc2_layer = nn.Linear(1800, num_emotions)
        self.softmax_out = nn.Softmax(dim=1)

    def forward(self, x):
        conv2d_embedding1 = self.conv2Dblock1(x)
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim = 1)

        conv2d_embedding2 = self.conv2Dblock2(x)
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim = 1)

        x_maxpool = self.transformer_maxpool(x)
        # x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        x_maxpool_reduced = x_maxpool.resize(x_maxpool.shape[0], 40, 450)
        x = x_maxpool_reduced.permute(2,0,1) #rearrange dims
        transformer_output = self.transformer_encoder(x)
        transformer_embedding = torch.mean(transformer_output, dim = 0)

        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2, transformer_embedding], dim = 1)
        fc1 = self.fc1_layer(complete_embedding)
        ac1 = self.act1(fc1)
        output_logits = self.fc2_layer(ac1)
        output_softmax = self.softmax_out(output_logits)
        return output_logits, output_softmax

# %%
# # file = "/kaggle/input/dpl-project-1/test_data/raw_datas/negative/Xuyen_01.m4a"

# os.makedirs("/kaggle/working/wav_datas/negative")
# os.makedirs("/kaggle/working/wav_datas/neutral")
# os.makedirs("/kaggle/working/wav_datas/positive")
# os.makedirs("/kaggle/working/denoised_datas/negative")
# os.makedirs("/kaggle/working/denoised_datas/neutral")
# os.makedirs("/kaggle/working/denoised_datas/positive")

# %%
import os

# Directory paths
directories_to_create = [
    "/kaggle/working/wav_datas/negative",
    "/kaggle/working/wav_datas/neutral",
    "/kaggle/working/wav_datas/positive",
    "/kaggle/working/denoised_datas/negative",
    "/kaggle/working/denoised_datas/neutral",
    "/kaggle/working/denoised_datas/positive"
]

# Create directories with exist_ok=True to prevent errors
for directory in directories_to_create:
    os.makedirs(directory, exist_ok=True)

# %%
# output_file = file.replace('/kaggle/input/dpl-project-1/test_data/raw_datas', '/kaggle/working/wav_datas')
# output_file = output_file.split('.')[0] + ".wav"
# # !pip install ffmpeg-python
# import ffmpeg
# ffmpeg.input(file).output(output_file).run()
# # subprocess.call(['ffmpeg', '-i', file,"-i", output_file])

# %%
# print(output_file)

# %%
class preprocess_real_data():
    def __init__(self,file):
      self.file = file
    def mp4_to_wav(self, file):
        output_file = file.replace('/kaggle/input/dpl-project-1/test_data/raw_datas', '/kaggle/working/wav_datas')
        output_file = output_file.split('.')[0] + ".wav"
        # !pip install ffmpeg-python
        #import ffmpeg
        ffmpeg.input(file).output(output_file, y='-y').run()

        # subprocess.call(['ffmpeg', '-i', file,"-i", output_file])
        return output_file
    def remove_noise(self, file):
        # Detect non-silent parts of the audio
        sound_file = AudioSegment.from_wav(file)
        non_sil_times = detect_nonsilent(sound_file, min_silence_len=400, silence_thresh=sound_file.dBFS * 0.65)
        # Concatenate the non-silent parts of the audio
        if len(non_sil_times) > 0:
            non_sil_times_concat = [non_sil_times[0]]
            if len(non_sil_times) > 1:
                for t in non_sil_times[1:]:
                    if t[0] - non_sil_times_concat[-1][1] < 100:
                        non_sil_times_concat[-1] = (non_sil_times_concat[-1][0], t[1])
                    else:
                        non_sil_times_concat.append(t)
            new_audio = sound_file[non_sil_times_concat[0][0]:non_sil_times_concat[0][1]]
            for t in non_sil_times_concat[1:]:
                new_audio += sound_file[t[0]:t[1]]
        else:
            new_audio = sound_file

        # Export the new audio file
        file_name = file.replace('wav_datas', 'denoised_datas')
        file_name = file_name[:-4]+'_denoised.wav'
        new_audio.export(file_name, format="wav")
        return file_name
    def resize(self, file):
        tensor = torch.load(file)
        n = tensor.shape[-1]//900 + 1
        sample = torch.zeros((2,40,n * 900))
        sample[:,:,:tensor.shape[-1]] = tensor
        sample = sample.reshape((2,40,900,n)).permute(3,0,1,2)
        torch.save(sample,file)
#         sample = torch.transpose(torch.transpose(sample1.reshape((40,500,n)),dim0=0, dim1=2),dim0=1, dim1=2).reshape((n,1,40,500))
        return sample
    def save_tensor_file(self, file):
        waveform, sample_rate = torchaudio.load(file)
        transform = torchaudio.transforms.MFCC(sample_rate=sample_rate)
        mfcc = transform(waveform)
        file_name = file[:-4]+'.pt'
        torch.save(mfcc,file_name)
        return file_name
    def complete_preprocessing(self, file):
      file = self.mp4_to_wav(file)
      file = self.remove_noise(file)
      file = self.save_tensor_file(file)
      tensor = self.resize(file)
      return file, tensor

# %%
def load_model(model_path):
    model = define_model(3)
    model.eval()
    model.load_state_dict(torch.load(model_path, map_location='cpu'))
#     model.load_state_dict(torch.load(model_path))
    return model

# %%
model = load_model('/kaggle/input/update-mode/model78.pt')
# model = torch.load('/kaggle/input/dpl-project/model_update1.pt', map_location='cpu')
# model.load_state_dict(torch.load('model.pt'))
# model.parameters()
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Total number of trainable parameters: {num_params}')
# Out:
# Total number of trainable parameters: 6770659

# %%
def predict_1_sample(file_sample, model):
    tensor = torch.load(file_sample)
    output_logit, output_softmax = model(tensor)
    output_softmax = torch.argmax(output_softmax, dim=1)
    final_output = max(set(output_softmax.tolist()), key=output_softmax.tolist().count)
    emotion_dict = {0: 'positive',
                    1: 'neutral',
                    2: 'negative'}
    label = emotion_dict[final_output]
    return final_output, label

# %%
def extract_label_file(root):
  header = ['sessionID','labels','path']
  emotion_dict = {
      'positive': 0,
      'neutral': 1,
      'negative': 2
  }
  with open('test_real_data.csv',mode='w',newline='') as file:
          write = csv.writer(file)
          write.writerow(header)
  df = pd.read_csv('test_real_data.csv')
  for file in os.listdir(root):
          for sample in os.listdir(os.path.join(root, file)):
              processer = preprocess_real_data(0)
              path_sample, tensor = processer.complete_preprocessing(os.path.join(root, file, sample))
              sample_info = {'sessionID': sample, 'labels': emotion_dict[file],'path': path_sample}
              df = pd.concat([df, pd.DataFrame([sample_info])], ignore_index=True)
  df.to_csv('test_real_data.csv')

# %%
def test_real_data(model_file):
  df = pd.read_csv('/kaggle/working/test_real_data.csv')
  df = df.sort_values('labels')
  model = load_model(model_file)
  preprocesser = preprocess_real_data('ok')
  y = df.labels
  y = torch.as_tensor(y)
  y_hat = torch.zeros(len(y))
  ind_sample = 0
  for sample in df.path:
    final_output, label = predict_1_sample(sample, model)
    y_hat[ind_sample] = final_output
    ind_sample += 1
  df.to_csv('/kaggle/working/test_real_data.csv')
  return y, y_hat

# %%
root ='/kaggle/input/dpl-project-1/test_data/raw_datas'
extract_label_file(root)
model_file = '/kaggle/input/update-mode/model78.pt'
y, y_hat = test_real_data(model_file)
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_05.m4a':
#   Metadata:
#     major_brand     : 3gp4
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2023-10-26T13:10:10.000000Z
#     com.android.version: 12
#   Duration: 00:00:22.38, start: 0.000000, bitrate: 141 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T13:10:10.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/chien_05.wav':
#   Metadata:
#     major_brand     : 3gp4
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     com.android.version: 12
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T13:10:10.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1928kB time=00:00:22.35 bitrate= 706.4kbits/s speed= 652x
# video:0kB audio:1928kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003951%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_03.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T10:32:32.000000Z
#     title           : Neutral04
#     voice-memo-uuid : 54372E0B-4FD2-40CD-9529-85AA9FF04503
#     encoder         : com.apple.VoiceMemos (iPhone Version 17.0.3 (Build 21A360))
#   Duration: 00:00:06.25, start: 0.000000, bitrate: 72 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 65 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T10:32:32.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/Xuyen_03.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : 54372E0B-4FD2-40CD-9529-85AA9FF04503
#     INAM            : Neutral04
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T10:32:32.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     590kB time=00:00:06.27 bitrate= 770.7kbits/s speed= 391x
# video:0kB audio:590kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015890%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_10.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T11:09:33.000000Z
#     title           : Neutral11
#     voice-memo-uuid : 1688CF79-1EEC-4C9D-8D53-0905F3FA7098
#     encoder         : com.apple.VoiceMemos (iPhone Version 17.0.3 (Build 21A360))
#   Duration: 00:00:05.88, start: 0.000000, bitrate: 71 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:09:33.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/Xuyen_10.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : 1688CF79-1EEC-4C9D-8D53-0905F3FA7098
#     INAM            : Neutral11
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:09:33.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     556kB time=00:00:05.90 bitrate= 770.9kbits/s speed= 378x
# video:0kB audio:556kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016862%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x58bbcf0ed580] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_14.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2023-10-26T17:26:19.000000Z
#     iTunSMPB        :  00000000 00000840 000002D0 00000000000BF4F0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     copyright       : iPhone
#     album           : Ghi âm X
#     comment         :
#     date            : 2023
#     genre           : Bản ghi
#     encoder         : Ghi âm X
#   Duration: 00:00:16.38, start: 0.044000, bitrate: 97 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T17:26:19.000000Z
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Video: png, ya8(pc), 102x102 [SAR 8504:8504 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/tinh_14.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     IGNR            : Bản ghi
#     iTunSMPB        :  00000000 00000840 000002D0 00000000000BF4F0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     ICOP            : iPhone
#     IPRD            : Ghi âm X
#     ICMT            :
#     ICRD            : 2023
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T17:26:19.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1532kB time=00:00:16.31 bitrate= 769.1kbits/s speed= 442x
# video:0kB audio:1532kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.009180%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mp3 @ 0x56723b73f580] Estimating duration from bitrate, this may be inaccurate
# Input #0, mp3, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_09.mp3':
#   Duration: 00:00:22.08, start: 0.000000, bitrate: 320 kb/s
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 320 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/chien_09.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# [mp3float @ 0x56723b743c00] Header missing/A speed=N/A
# Error while decoding stream #0:0: Invalid data found when processing input
# size=    4136kB time=00:00:22.03 bitrate=1537.7kbits/s speed= 227x
# video:0kB audio:4136kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001842%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_14.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T11:28:06.000000Z
#     title           : Neutral16
#     voice-memo-uuid : 40DF6104-92D3-4BD5-8E39-DC86AB855C31
#     encoder         : com.apple.VoiceMemos (iPhone Version 17.0.3 (Build 21A360))
#   Duration: 00:00:04.89, start: 0.000000, bitrate: 72 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:28:06.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/Xuyen_14.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : 40DF6104-92D3-4BD5-8E39-DC86AB855C31
#     INAM            : Neutral16
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:28:06.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     464kB time=00:00:04.92 bitrate= 771.5kbits/s speed= 354x
# video:0kB audio:464kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020205%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x574e06ff1580] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_7.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2023-10-26T16:47:37.000000Z
#     iTunSMPB        :  00000000 00000840 00000190 00000000000D0E30 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     copyright       : iPhone
#     album           : Ghi âm X
#     comment         :
#     date            : 2023
#     genre           : Bản ghi
#     encoder         : Ghi âm X
#   Duration: 00:00:17.88, start: 0.044000, bitrate: 93 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 63 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:47:37.000000Z
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Video: png, ya8(pc), 102x102 [SAR 8504:8504 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/tinh_7.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     IGNR            : Bản ghi
#     iTunSMPB        :  00000000 00000840 00000190 00000000000D0E30 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     ICOP            : iPhone
#     IPRD            : Ghi âm X
#     ICMT            :
#     ICRD            : 2023
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:47:37.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1672kB time=00:00:17.81 bitrate= 769.0kbits/s speed= 421x
# video:0kB audio:1672kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008411%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x57c409cf2580] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_9.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2023-10-26T16:50:52.000000Z
#     iTunSMPB        :  00000000 00000840 00000270 00000000000D7550 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     copyright       : iPhone
#     album           : Ghi âm X
#     comment         :
#     date            : 2023
#     genre           : Bản ghi
#     encoder         : Ghi âm X
#   Duration: 00:00:18.43, start: 0.044000, bitrate: 92 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 63 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:50:52.000000Z
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Video: png, ya8(pc), 102x102 [SAR 8504:8504 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/tinh_9.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     IGNR            : Bản ghi
#     iTunSMPB        :  00000000 00000840 00000270 00000000000D7550 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     ICOP            : iPhone
#     IPRD            : Ghi âm X
#     ICMT            :
#     ICRD            : 2023
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:50:52.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1724kB time=00:00:18.36 bitrate= 769.0kbits/s speed= 428x
# video:0kB audio:1724kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008157%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x59dbd29e4580] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/tinh_8.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2023-10-26T16:48:13.000000Z
#     iTunSMPB        :  00000000 00000840 00000040 00000000000A1B80 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     copyright       : iPhone
#     album           : Ghi âm X
#     comment         :
#     date            : 2023
#     genre           : Bản ghi
#     encoder         : Ghi âm X
#   Duration: 00:00:13.85, start: 0.044000, bitrate: 102 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 63 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:48:13.000000Z
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Video: png, ya8(pc), 102x102 [SAR 8504:8504 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/tinh_8.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     IGNR            : Bản ghi
#     iTunSMPB        :  00000000 00000840 00000040 00000000000A1B80 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     ICOP            : iPhone
#     IPRD            : Ghi âm X
#     ICMT            :
#     ICRD            : 2023
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:48:13.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1294kB time=00:00:13.78 bitrate= 769.3kbits/s speed= 428x
# video:0kB audio:1294kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010869%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_12.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T11:12:22.000000Z
#     title           : Neutral14
#     voice-memo-uuid : F20A01E9-481F-4570-A186-7ACF875BA7AE
#     encoder         : com.apple.VoiceMemos (iPhone Version 17.0.3 (Build 21A360))
#   Duration: 00:00:05.23, start: 0.000000, bitrate: 71 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:12:22.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/Xuyen_12.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : F20A01E9-481F-4570-A186-7ACF875BA7AE
#     INAM            : Neutral14
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:12:22.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     496kB time=00:00:05.26 bitrate= 771.3kbits/s speed= 364x
# video:0kB audio:496kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018901%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_01.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T10:30:46.000000Z
#     title           : Neural03
#     voice-memo-uuid : B175DE9F-BD28-4138-8E51-B166016C2D5C
#     encoder         : com.apple.VoiceMemos (iPhone Version 17.0.3 (Build 21A360))
#   Duration: 00:00:03.62, start: 0.000000, bitrate: 74 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 66 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T10:30:46.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/Xuyen_01.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : B175DE9F-BD28-4138-8E51-B166016C2D5C
#     INAM            : Neural03
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T10:30:46.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     344kB time=00:00:03.64 bitrate= 772.7kbits/s speed= 328x
# video:0kB audio:344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027253%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mp3, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_08.mp3':
#   Metadata:
#     encoder         : Lavf60.4.100
#   Duration: 00:00:47.10, start: 0.025057, bitrate: 128 kb/s
#   Stream #0:0: Audio: mp3, 44100 Hz, stereo, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (mp3 (mp3float) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/chien_08.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, stereo, s16, 1411 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    8109kB time=00:00:47.04 bitrate=1412.0kbits/s speed= 328x
# video:0kB audio:8109kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000939%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/chien_06.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T15:44:12.000000Z
#     title           : Nguyễn Tri Phương 3
#     voice-memo-uuid : 500E21F3-B0EE-45B1-9892-E5C0BC7CC553
#     encoder         : com.apple.VoiceMemos (iPhone của H (null))
#   Duration: 00:00:13.36, start: 0.000000, bitrate: 69 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T15:44:12.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/chien_06.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : 500E21F3-B0EE-45B1-9892-E5C0BC7CC553
#     INAM            : Nguyễn Tri Phương 3
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T15:44:12.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1258kB time=00:00:13.39 bitrate= 769.3kbits/s speed= 396x
# video:0kB audio:1258kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.008539%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/neutral/Xuyen_11.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T11:10:25.000000Z
#     title           : Neutral12
#     voice-memo-uuid : 64BEAAE6-451F-4529-8C4B-E44375CC869F
#     encoder         : com.apple.VoiceMemos (iPhone Version 17.0.3 (Build 21A360))
#   Duration: 00:00:03.17, start: 0.000000, bitrate: 73 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:10:25.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/neutral/Xuyen_11.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : 64BEAAE6-451F-4529-8C4B-E44375CC869F
#     INAM            : Neutral12
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:10:25.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     302kB time=00:00:03.20 bitrate= 773.4kbits/s speed= 316x
# video:0kB audio:302kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.031043%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
# ...
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x555de84a8580] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_15.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2023-10-26T17:38:38.000000Z
#     iTunSMPB        :  00000000 00000840 000000E0 00000000000F6AE0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     copyright       : iPhone
#     album           : Ghi âm X
#     comment         :
#     date            : 2023
#     genre           : Bản ghi
#     encoder         : Ghi âm X
#   Duration: 00:00:21.10, start: 0.044000, bitrate: 89 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T17:38:38.000000Z
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Video: png, ya8(pc), 102x102 [SAR 8504:8504 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/positive/tinh_15.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     IGNR            : Bản ghi
#     iTunSMPB        :  00000000 00000840 000000E0 00000000000F6AE0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     ICOP            : iPhone
#     IPRD            : Ghi âm X
#     ICMT            :
#     ICRD            : 2023
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T17:38:38.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1974kB time=00:00:21.03 bitrate= 768.8kbits/s speed= 466x
# video:0kB audio:1974kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007124%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/positive/chien_10.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isom
#     creation_time   : 2023-10-26T12:29:25.000000Z
#   Duration: 00:00:04.18, start: 0.000000, bitrate: 176 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 66 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T12:29:25.000000Z
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/positive/chien_10.wav':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: mp42isom
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T12:29:25.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     360kB time=00:00:04.15 bitrate= 709.7kbits/s speed= 363x
# video:0kB audio:360kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.021159%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/positive/Xuyen_04.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     creation_time   : 2023-10-26T11:17:40.000000Z
#     title           : Positive10
#     voice-memo-uuid : 196908EA-32E0-4E06-BEAF-FC596A904BFA
#     encoder         : com.apple.VoiceMemos (iPhone Version 17.0.3 (Build 21A360))
#   Duration: 00:00:06.56, start: 0.000000, bitrate: 70 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 64 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:17:40.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/positive/Xuyen_04.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A isommp42
#     voice-memo-uuid : 196908EA-32E0-4E06-BEAF-FC596A904BFA
#     INAM            : Positive10
#     ISFT            : Lavf58.76.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T11:17:40.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=     620kB time=00:00:06.59 bitrate= 770.6kbits/s speed= 372x
# video:0kB audio:620kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015436%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [aac @ 0x5855f33b8580] Estimating duration from bitrate, this may be inaccurate
# Input #0, aac, from '/kaggle/input/dpl-project-1/test_data/raw_datas/positive/Nhat_10.aac':
#   Duration: 00:00:09.62, bitrate: 194 kb/s
#   Stream #0:0: Audio: aac (LC), 48000 Hz, stereo, fltp, 194 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/positive/Nhat_10.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    1804kB time=00:00:09.60 bitrate=1539.5kbits/s speed= 275x
# video:0kB audio:1804kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004222%
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5b42c1ec8580] stream 0, timescale not set
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/kaggle/input/dpl-project-1/test_data/raw_datas/positive/tinh_1.m4a':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     creation_time   : 2023-10-26T16:09:27.000000Z
#     iTunSMPB        :  00000000 00000840 00000310 00000000001198B0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     copyright       : iPhone
#     album           : Ghi âm X
#     comment         :
#     date            : 2023
#     genre           : Bản ghi
#     encoder         : Ghi âm X
#   Duration: 00:00:24.09, start: 0.044000, bitrate: 85 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 63 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:09:27.000000Z
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Video: png, ya8(pc), 102x102 [SAR 8504:8504 DAR 1:1], 90k tbr, 90k tbn, 90k tbc (attached pic)
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/kaggle/working/wav_datas/positive/tinh_1.wav':
#   Metadata:
#     major_brand     : M4A
#     minor_version   : 0
#     compatible_brands: M4A mp42isom
#     IGNR            : Bản ghi
#     iTunSMPB        :  00000000 00000840 00000310 00000000001198B0 00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#     ICOP            : iPhone
#     IPRD            : Ghi âm X
#     ICMT            :
#     ICRD            : 2023
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, mono, s16, 768 kb/s (default)
#     Metadata:
#       creation_time   : 2023-10-26T16:09:27.000000Z
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    2254kB time=00:00:24.02 bitrate= 768.7kbits/s speed= 448x
# video:0kB audio:2254kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006239%

# %%
def metric(y, y_hat):
  df = pd.read_csv('/kaggle/working/test_real_data.csv')
  labels = {'positive':0,'neutral':0,'negative':0}
  start_num = 0
  for i, label in enumerate(labels):
    end_num = start_num+len(df.loc[df.labels == i])
    TP = torch.sum(y[start_num:end_num] == y_hat[start_num:end_num])
    the_last = torch.cat((y_hat[:start_num],y_hat[end_num:]))
    FP = torch.count_nonzero( the_last == i)
    FN = torch.count_nonzero( y_hat[start_num:end_num] != i)
#     print('Precision of',label, ': ', TP/(TP+FP))
    F1 = 2*TP / (2*TP+FP+FN)
    labels[label] = round(F1.item(),2)
    start_num = end_num
  accuracy = torch.sum(y==y_hat)/float(len(y))
  print('F1_score of every label: ', labels)
  print('Average F1: ',round(statistics.mean(labels.values()),2))
  print('Accuracy: ', accuracy)

# %%
metric(y, y_hat)
# Out:
# F1_score of every label:  {'positive': 0.24, 'neutral': 0.43, 'negative': 0.15}
# Average F1:  0.27
# Accuracy:  tensor(0.3099)
